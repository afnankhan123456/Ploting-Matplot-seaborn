# %% [markdown]
# # pairplot

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rock = pd.read_csv(r"C:\Users\AFNAN KHAN.DESKTOP-UAK9PNT\Desktop\New folder\tips.csv")
rock
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(rock)
# Out:
# F:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# yadi hum two ya koi particular  column nikalna chahe

sns.pairplot(vars[['total_bill', 'tip']])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 # yadi hum two ya koi particular  column nikalna chahe
# ----> 3 sns.pairplot(vars[['total_bill', 'tip']])
#       4 plt.show()
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
sns.pairplot(rock[['total_bill', 'tip', 'sex']], hue='sex')
plt.show()
# Out:
# F:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(rock[['total_bill', 'tip', 'sex']], hue='sex', hue_order=['female', 'male'])
plt.show()
# Out:
# F:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Note Vars ka use randome ke liye kiya gya he
sns.pairplot(rock, hue='sex', hue_order=['female', 'male'], vars=['total_bill', 'tip'])

plt.show()
# Out:
# F:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# kind='reg'   graph change krne ke liye
# kind='reg'   graph change krne ke liye
  

sns.pairplot(rock[['total_bill', 'tip', 'sex']], hue='sex', kind='kde')
plt.show()
# Out:
# F:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
